# %% [markdown]
# ## Assignment: Coffee Shop

# %%
#Michael Tzehaie
#04/05/2022


small_cost = 2.0
medium_cost = 3.0
large_cost = 4.0

size = input("Do you want small, medium, or large? ").lower()
method = input("Do you want brewed, espresso, or cold brew? ").lower()
syrup = input("Do you want a flavored syrup? (yes or no)  ").lower()


if syrup == 'yes':
    flavour = input("Do you want hazelnut, vanilla, or caramel?  ").lower()
    print("You asked for a", size ,"cup of", method ,"coffee with", flavour ,"syrup")
    
else:
    print("You asked for a", size ,"cup of", method ,"coffee")

    

if size == 'small' and method == 'brewed':
    stotal = small_cost
    
if size == 'small' and method == 'espresso':
    stotal = 0.5 + small_cost
    
if size == 'small' and method == 'cold brew':
    stotal = 1 + small_cost
    
if size == 'small' and syrup == 'yes':
        p = stotal + 0.5
        print("Your cup of coffee costs", p)
        s = int(p)
        x = (s * 0.15) + p
        print("The price with a tip is %.2f" % t)
      
        
elif size == 'small' and syrup == 'no':
        p = stotal 
        print("Your cup of coffee costs", p)
        s = int(p)
        t = (s * 0.15) + p
        print("The price with a tip is %.2f" % t)
          
    
    
    
if size == 'medium' and method == 'brewed':
    mtotal = medium_cost
    
if size == 'medium' and method == 'espresso':
    mtotal = 0.5 + medium_cost   
    
if size == 'medium' and method == 'cold brew':
    mtotal = 1 + medium_cost
    

if size == 'medium' and syrup == 'yes':
        p = mtotal + 0.5
        print("Your cup of coffee costs", p)
        m = int(p)
        t = (m * 0.15) + p
        print("The price with a tip is %.2f" % t)
        
        
        
        
elif size == 'medium' and syrup == 'no':
        p = mtotal 
        print("Your cup of coffee costs", p)
        m = int(p)
        t = (m * 0.15) + p
        print("The price with a tip is %.2f" % t)
    
    
      
    
if size == 'large' and method == 'brewed':
    ltotal = large_cost
    
if size == 'large' and method == 'espresso':
    ltotal = 0.5 + large_cost
     
if size == 'large' and method == 'cold brew':
    ltotal = 1 + large_cost
    

if size == 'large' and syrup == 'yes':
        p = ltotal + 0.5
        print("Your cup of coffee costs", p)
        l = int(p)
        t = (l * 0.15) + p
        print("The price with a tip is %.2f" % t)
        
        
elif size == 'large' and syrup == 'no':
        p = ltotal 
        print("Your cup of coffee costs", p)
        l = int(p)
        t = (l * 0.15) + p
        print("The price with a tip is %.2f" % t)
# Out:
# Do you want small, medium, or large? large
# Do you want brewed, espresso, or cold brew? Cold brew
# Do you want a flavored syrup? (yes or no)  Yes
# Do you want hazelnut, vanilla, or caramel?  Caramel
# You asked for a large cup of cold brew coffee with caramel syrup
# Your cup of coffee costs 5.5
# The price with a tip is 6.25
